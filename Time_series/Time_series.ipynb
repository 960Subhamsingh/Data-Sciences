# %% [markdown]
# https://github.com/krishnaik06/Live-Time-Series/tree/main

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
from matplotlib import pyplot as plt 
# from statsmodels.tsa.api import  exponential_smoothing as ets , simpleExpsmoothing, holt
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings("ignore")

# %%
# df1 = pd.read_csv("AirPassengers.csv")

df = pd.read_csv("gold_monthly_csv.csv")

# %%
print(f"Date range of gold prices available from  - {df.loc[:,'Date'][0]} to {df.loc[:,'Date'][len(df)-1]} ")
# Out:
# Date range of gold prices available from  - 1950-01 to 2020-07

# %%
date = pd.date_range(start='1/1/1950', end='8/1/2020', freq='M')
date
# Out:
# DatetimeIndex(['1950-01-31', '1950-02-28', '1950-03-31', '1950-04-30',
#                '1950-05-31', '1950-06-30', '1950-07-31', '1950-08-31',
#                '1950-09-30', '1950-10-31',
#                ...
#                '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31',
#                '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31',
#                '2020-06-30', '2020-07-31'],
#               dtype='datetime64[ns]', length=847, freq='ME')

# %%
df.columns
# Out:
# Index(['Price', 'month'], dtype='object')

# %%
df['month']=date
# df.drop('date',axis=1, inplace=True )
df = df.set_index('month')
df.head()
# Out:
#             Price
# month
# 1950-01-31  34.73
# 1950-02-28  34.73
# 1950-03-31  34.73
# 1950-04-30  34.73
# 1950-05-31  34.73

# %%
df.plot(figsize=(12,6))
plt.title("Gold Prices monthly since 1950 and onwards")
plt.xlabel("month")
plt.ylabel('price')
plt.grid()
plt.show()
