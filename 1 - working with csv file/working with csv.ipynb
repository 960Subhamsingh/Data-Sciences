# %% [markdown]
# 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# 2. Show the pandas version

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# 3. Show the pandas version info

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : d9cdd2ee5a58015ef6f4d15c7226110c9aab8140
# python                : 3.10.11.final.0
# python-bits           : 64
# OS                    : Windows
# OS-release            : 10
# Version               : 10.0.19045
# machine               : AMD64
# processor             : AMD64 Family 21 Model 112 Stepping 0, AuthenticAMD
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : English_United States.1252
#
# pandas                : 2.2.2
# numpy                 : 1.26.4
# pytz                  : 2024.1
# dateutil              : 2.9.0.post0
# setuptools            : 65.5.0
# pip                   : 24.1
# Cython                : None
# pytest                : None
# hypothesis            : None
# sphinx                : None
# blosc                 : None
# feather               : None
# xlsxwriter            : None
# lxml.etree            : 5.2.2
# ...

# %% [markdown]
# 4. open csv file with the use of pandas library function

# %%
df= pd.read_csv('train.csv')
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# 5. sep parameter  and  add column name of movie_titles.tsv file

# %%
pd.read_csv("movie_titles .tsv" ,sep='\t' ,names=['S.No','Name','realse_year','rating','votes','genres'])
# Out:
#      S.No                        Name realse_year  rating     votes  \
# 0      m0  10 things i hate about you        1999     6.9   62847.0
# 1      m1  1492: conquest of paradise        1992     6.2   10421.0
# 2      m2                  15 minutes        2001     6.1   25854.0
# 3      m3       2001: a space odyssey        1968     8.4  163227.0
# 4      m4                     48 hrs.        1982     6.9   22289.0
# ..    ...                         ...         ...     ...       ...
# 612  m612                    watchmen        2009     7.8  135229.0
# 613  m613                         xxx        2002     5.6   53505.0
# 614  m614                       x-men        2000     7.4  122149.0
# 615  m615          young frankenstein        1974     8.0   57618.0
# 616  m616                   zulu dawn        1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# 6. see the index_col paramater

# %%
pd.read_csv('train.csv' , index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# 7. use columns parameter

# %%
pd.read_csv('train.csv' , usecols=['enrollee_id', 'city','gender','education_level','date'])

# %% [markdown]
# 8. see the selected column in train.csv file

# %%
df[['enrollee_id','city','education_level','gender']]

# %% [markdown]
# 9. see the squeeze parameters in train.csv file to the use column

# %%
pd.read_csv('train.csv', usecols=['gender']).head(10).squeeze()
# Out:
# 0    Male
# 1    Male
# 2     NaN
# 3     NaN
# 4    Male
# 5     NaN
# 6    Male
# 7    Male
# 8    Male
# 9     NaN
# Name: gender, dtype: object

# %% [markdown]
# 10. nrows parameter are showing to the user has  provide some number

# %%
pd.read_csv('train.csv', nrows=20 , encoding='latin-1')

# %% [markdown]
# 11. datatypes parameter  see in train.csv file

# %%
pd.read_csv('train.csv', dtype={'target':int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int32
# ...

# %% [markdown]
# 12. skprow parameter

# %%
pd.read_csv('train.csv',skiprows=12)
# Out:
#        23853  city_103   0.92  Male  Has relevent experience  \
# 0      25619   city_61  0.913  Male  Has relevent experience
# 1       5826   city_21  0.624  Male   No relevent experience
# 2       8722   city_21  0.624   NaN   No relevent experience
# 3       6588  city_114  0.926  Male  Has relevent experience
# 4       4167  city_103  0.920   NaN  Has relevent experience
# ...      ...       ...    ...   ...                      ...
# 19141   7386  city_173  0.878  Male   No relevent experience
# 19142  31398  city_103  0.920  Male  Has relevent experience
# 19143  24576  city_103  0.920  Male  Has relevent experience
# 19144   5756   city_65  0.802  Male  Has relevent experience
# 19145  23834   city_67  0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate        STEM    5  5000-9999  Pvt Ltd  \
# 0         no_enrollment        Graduate        STEM  >20  1000-4999  Pvt Ltd
# ...

# %% [markdown]
# 13. date parameter

# %%
pd.read_csv('train.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# ...

# %% [markdown]
# 14. Convertors

# %%
import numpy as np

# %%
def rename(gender):
    if(gender == "Male"):
        return "Male"
    elif(gender == np.NaN):
        return "female"
    else:
        return gender
rename("female")
# Out:
# 'female'

# %%
pd.read_csv('train.csv' , na_values=['gender',] , converters={'gender': rename}).head(12)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624
# 3         33241  city_115                   0.789
# 4           666  city_162                   0.767   Male
# 5         21651  city_176                   0.764
# 6         28806  city_160                   0.920   Male
# 7           402   city_46                   0.762   Male
# 8         27107  city_103                   0.920   Male
# 9           699  city_103                   0.920
# 10        29452   city_21                   0.624
# 11        23853  city_103                   0.920   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# 15. na_values parameter

# %%
pd.read_csv('train.csv' , na_values=['gender',] ).head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# 16. hearder parameter remove the one row of the exit csv file

# %%
pd.read_csv('train.csv', header=0)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# 17. open csv file from an URL

# %%
import requests
from io import StringIO
file = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"

req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[166], line 5
#       2 from io import StringIO
#       3 file = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
# ----> 5 req = requests.get(url, headers=headers)
#       6 data = StringIO(req.text)
#       8 pd.read_csv(data)
#
# NameError: name 'url' is not defined

# %% [markdown]
# 18. open the  csv file  to the use  read_table function

# %%
read_table = pd.read_table('train.csv',delimiter=',' ,skiprows=range(1,4))
read_table
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0            33241  city_115                   0.789    NaN
# 1              666  city_162                   0.767   Male
# 2            21651  city_176                   0.764    NaN
# 3            28806  city_160                   0.920   Male
# 4              402   city_46                   0.762   Male
# ...            ...       ...                     ...    ...
# 19150         7386  city_173                   0.878   Male
# 19151        31398  city_103                   0.920   Male
# 19152        24576  city_103                   0.920   Male
# 19153         5756   city_65                   0.802   Male
# 19154        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0       No relevent experience                 NaN        Graduate
# 1      Has relevent experience       no_enrollment         Masters
# ...

# %%
import yfinance as yf

def get_income_statement(ticker):
    # Fetch income statement data from Yahoo Finance
    stock = yf.Ticker(ticker)
    income_statement = stock.financials.loc['Net Income']
    return income_statement
def analyze_income_statement(income_statement):
    # Calculate metrics or perform analysis
    # Example: calculate average net income over the last 5 years
    avg_net_income = income_statement.mean()
    return avg_net_income

if __name__ == "__main__":
    # Example usage
    ticker_symbol = "AAPL"  # Apple Inc. as an example
    income_statement = get_income_statement(ticker_symbol)
    avg_net_income = analyze_income_statement(income_statement)
    print("Average Net Income:", avg_net_income)
# Out:
# Average Net Income: 87222250000.0
