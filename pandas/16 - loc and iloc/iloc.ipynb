# %%
import pandas as pd

# %%
data = pd.read_csv("E:/Datasets/Datasets-master/cars.csv")

# %%
data.iloc[3]
# Out:
# YEAR                       2013
# Make                 MITSUBISHI
# Model                    i-MiEV
# Size                 SUBCOMPACT
# (kW)                         49
# Unnamed: 5                   A1
# TYPE                          B
# CITY (kWh/100 km)          16.9
# HWY (kWh/100 km)           21.4
# COMB (kWh/100 km)          18.7
# CITY (Le/100 km)            1.9
# HWY (Le/100 km)             2.4
# COMB (Le/100 km)            2.1
# (g/km)                        0
# RATING                      NaN
# (km)                        100
# TIME (h)                      7
# Name: 3, dtype: object

# %%
data.iloc[:,3].head()
# Out:
# 0    SUBCOMPACT
# 1      MID-SIZE
# 2       COMPACT
# 3    SUBCOMPACT
# 4      MID-SIZE
# Name: Size, dtype: object

# %%
data.iloc[2:8,2:8]
# Out:
#                              Model        Size  (kW) Unnamed: 5 TYPE  \
# 2                   FOCUS ELECTRIC     COMPACT   107         A1    B
# 3                           i-MiEV  SUBCOMPACT    49         A1    B
# 4                             LEAF    MID-SIZE    80         A1    B
# 5  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35         A1    B
# 6      FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35         A1    B
# 7         MODEL S (40 kWh battery)   FULL-SIZE   270         A1    B
#
#    CITY (kWh/100 km)
# 2               19.0
# 3               16.9
# 4               19.3
# 5               17.2
# 6               17.2
# 7               22.4

# %%
data.iloc[[1,4,5,9,10,12], 4:8]
# Out:
#     (kW) Unnamed: 5 TYPE  CITY (kWh/100 km)
# 1     80         A1    B               19.3
# 4     80         A1    B               19.3
# 5     35         A1    B               17.2
# 9    270         A1    B               23.8
# 10   310         A1    B               23.9
# 12   107         A1    B               19.0

# %%
data.iloc[[2, 6, 10, 25, 28, 33]]
# Out:
#     YEAR    Make                        Model        Size  (kW) Unnamed: 5  \
# 2   2013    FORD               FOCUS ELECTRIC     COMPACT   107         A1
# 6   2013   SMART  FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35         A1
# 10  2013   TESLA          MODEL S PERFORMANCE   FULL-SIZE   310         A1
# 25  2015  NISSAN                         LEAF    MID-SIZE    80         A1
# 28  2015   TESLA     MODEL S (60 kWh battery)   FULL-SIZE   283         A1
# 33  2015   TESLA            MODEL S P85D/P90D   FULL-SIZE   515         A1
#
#    TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# 2     B               19.0              21.1               20.0
# 6     B               17.2              22.5               19.6
# 10    B               23.9              23.2               23.6
# 25    B               16.5              20.8               18.4
# 28    B               22.2              21.7               21.9
# 33    B               23.4              21.5               22.5
#
#     CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  \
# 2                2.1              2.4               2.2       0     NaN   122
# 6                1.9              2.5               2.2       0     NaN   109
# 10               2.7              2.6               2.6       0     NaN   426
# 25               1.9              2.3               2.1       0     NaN   135
# 28               2.5              2.4               2.5       0     NaN   335
# 33               2.6              2.4               2.5       0     NaN   407
#
#     TIME (h)
# 2          4
# 6          8
# 10        12
# 25         5
# 28        10
# 33        12

# %%
data.loc[0:5]
# Out:
#    YEAR        Make                            Model        Size  (kW)  \
# 0  2012  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 1  2012      NISSAN                             LEAF    MID-SIZE    80
# 2  2013        FORD                   FOCUS ELECTRIC     COMPACT   107
# 3  2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 4  2013      NISSAN                             LEAF    MID-SIZE    80
# 5  2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
#
#   Unnamed: 5 TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# 0         A1    B               16.9              21.4               18.7
# 1         A1    B               19.3              23.0               21.1
# 2         A1    B               19.0              21.1               20.0
# 3         A1    B               16.9              21.4               18.7
# 4         A1    B               19.3              23.0               21.1
# 5         A1    B               17.2              22.5               19.6
#
#    CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  \
# 0               1.9              2.4               2.1       0     NaN   100
# 1               2.2              2.6               2.4       0     NaN   117
# 2               2.1              2.4               2.2       0     NaN   122
# 3               1.9              2.4               2.1       0     NaN   100
# 4               2.2              2.6               2.4       0     NaN   117
# 5               1.9              2.5               2.2       0     NaN   109
#
#    TIME (h)
# 0         7
# 1         7
# 2         4
# 3         7
# 4         7
# 5         8

# %%
data.loc[[0,3,4,5] , ['YEAR','Make','Model','Size','(kW)']]
# Out:
#    YEAR        Make                            Model        Size  (kW)
# 0  2012  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 3  2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 4  2013      NISSAN                             LEAF    MID-SIZE    80
# 5  2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35

# %%
data.loc[(data['Make']=='TESLA') &(data['Model']=='MODEL S 70D'), ['Make','Model', 'Size', '(kW)']]
# Out:
#      Make        Model       Size  (kW)
# 31  TESLA  MODEL S 70D  FULL-SIZE   280
# 46  TESLA  MODEL S 70D  FULL-SIZE   386

# %%
data.loc[20]
# Out:
# YEAR                       2015
# Make                        BMW
# Model                        i3
# Size                 SUBCOMPACT
# (kW)                        125
# Unnamed: 5                   A1
# TYPE                          B
# CITY (kWh/100 km)          15.2
# HWY (kWh/100 km)           18.8
# COMB (kWh/100 km)          16.8
# CITY (Le/100 km)            1.7
# HWY (Le/100 km)             2.1
# COMB (Le/100 km)            1.9
# (g/km)                        0
# RATING                      NaN
# (km)                        130
# TIME (h)                      4
# Name: 20, dtype: object

# %%
df = data.set_index('YEAR')

# %%
df.loc[2013]
# Out:
#             Make                            Model        Size  (kW)  \
# YEAR
# 2013        FORD                   FOCUS ELECTRIC     COMPACT   107
# 2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 2013      NISSAN                             LEAF    MID-SIZE    80
# 2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
# 2013       SMART      FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35
# 2013       TESLA         MODEL S (40 kWh battery)   FULL-SIZE   270
# 2013       TESLA         MODEL S (60 kWh battery)   FULL-SIZE   270
# 2013       TESLA         MODEL S (85 kWh battery)   FULL-SIZE   270
# 2013       TESLA              MODEL S PERFORMANCE   FULL-SIZE   310
#
#      Unnamed: 5 TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# YEAR
# 2013         A1    B               19.0              21.1               20.0
# 2013         A1    B               16.9              21.4               18.7
# 2013         A1    B               19.3              23.0               21.1
# 2013         A1    B               17.2              22.5               19.6
# 2013         A1    B               17.2              22.5               19.6
# 2013         A1    B               22.4              21.9               22.2
# 2013         A1    B               22.2              21.7               21.9
# 2013         A1    B               23.8              23.2               23.6
# 2013         A1    B               23.9              23.2               23.6
#
#       CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  \
# YEAR
# 2013               2.1              2.4               2.2       0     NaN
# 2013               1.9              2.4               2.1       0     NaN
# 2013               2.2              2.6               2.4       0     NaN
# 2013               1.9              2.5               2.2       0     NaN
# 2013               1.9              2.5               2.2       0     NaN
# 2013               2.5              2.5               2.5       0     NaN
# 2013               2.5              2.4               2.5       0     NaN
# 2013               2.7              2.6               2.6       0     NaN
# 2013               2.7              2.6               2.6       0     NaN
#
#       (km)  TIME (h)
# YEAR
# 2013   122         4
# 2013   100         7
# 2013   117         7
# 2013   109         8
# 2013   109         8
# 2013   224         6
# 2013   335        10
# 2013   426        12
# 2013   426        12

# %%
df.loc[[2012, 2013, 2016]].head(5)
# Out:
#             Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# YEAR
# 2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#       CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# YEAR
# 2012               16.9              21.4               18.7
# 2012               19.3              23.0               21.1
# 2013               19.0              21.1               20.0
# 2013               16.9              21.4               18.7
# 2013               19.3              23.0               21.1
#
#       CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  \
# YEAR
# 2012               1.9              2.4               2.1       0     NaN
# 2012               2.2              2.6               2.4       0     NaN
# 2013               2.1              2.4               2.2       0     NaN
# 2013               1.9              2.4               2.1       0     NaN
# 2013               2.2              2.6               2.4       0     NaN
#
#       (km)  TIME (h)
# YEAR
# 2012   100         7
# 2012   117         7
# 2013   122         4
# 2013   100         7
# 2013   117         7

# %%
df.loc[2012]
# Out:
#             Make   Model        Size  (kW) Unnamed: 5 TYPE  CITY (kWh/100 km)  \
# YEAR
# 2012  MITSUBISHI  i-MiEV  SUBCOMPACT    49         A1    B               16.9
# 2012      NISSAN    LEAF    MID-SIZE    80         A1    B               19.3
#
#       HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  \
# YEAR
# 2012              21.4               18.7               1.9              2.4
# 2012              23.0               21.1               2.2              2.6
#
#       COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# YEAR
# 2012               2.1       0     NaN   100         7
# 2012               2.4       0     NaN   117         7

# %%
df.loc[2012:2016].head()
# Out:
#             Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# YEAR
# 2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#       CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# YEAR
# 2012               16.9              21.4               18.7
# 2012               19.3              23.0               21.1
# 2013               19.0              21.1               20.0
# 2013               16.9              21.4               18.7
# 2013               19.3              23.0               21.1
#
#       CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  \
# YEAR
# 2012               1.9              2.4               2.1       0     NaN
# 2012               2.2              2.6               2.4       0     NaN
# 2013               2.1              2.4               2.2       0     NaN
# 2013               1.9              2.4               2.1       0     NaN
# 2013               2.2              2.6               2.4       0     NaN
#
#       (km)  TIME (h)
# YEAR
# 2012   100         7
# 2012   117         7
# 2013   122         4
# 2013   100         7
# 2013   117         7

# %% [markdown]
# df.loc['rows','columns']

# %%
df.loc[2012:2014, 'Make':'(kW)']
# Out:
#             Make                            Model        Size  (kW)
# YEAR
# 2012  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 2012      NISSAN                             LEAF    MID-SIZE    80
# 2013        FORD                   FOCUS ELECTRIC     COMPACT   107
# 2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 2013      NISSAN                             LEAF    MID-SIZE    80
# 2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
# 2013       SMART      FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35
# 2013       TESLA         MODEL S (40 kWh battery)   FULL-SIZE   270
# 2013       TESLA         MODEL S (60 kWh battery)   FULL-SIZE   270
# 2013       TESLA         MODEL S (85 kWh battery)   FULL-SIZE   270
# 2013       TESLA              MODEL S PERFORMANCE   FULL-SIZE   310
# 2014   CHEVROLET                         SPARK EV  SUBCOMPACT   104
# 2014        FORD                   FOCUS ELECTRIC     COMPACT   107
# 2014  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 2014      NISSAN                             LEAF    MID-SIZE    80
# 2014       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
# 2014       SMART      FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35
# 2014       TESLA         MODEL S (60 kWh battery)   FULL-SIZE   225
# 2014       TESLA         MODEL S (85 kWh battery)   FULL-SIZE   270
# 2014       TESLA              MODEL S PERFORMANCE   FULL-SIZE   310

# %%
df.loc[2012:2014, ['Make', 'Model', 'TYPE', '(kW)', '(km)']]
# Out:
#             Make                            Model TYPE  (kW)  (km)
# YEAR
# 2012  MITSUBISHI                           i-MiEV    B    49   100
# 2012      NISSAN                             LEAF    B    80   117
# 2013        FORD                   FOCUS ELECTRIC    B   107   122
# 2013  MITSUBISHI                           i-MiEV    B    49   100
# 2013      NISSAN                             LEAF    B    80   117
# 2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET    B    35   109
# 2013       SMART      FORTWO ELECTRIC DRIVE COUPE    B    35   109
# 2013       TESLA         MODEL S (40 kWh battery)    B   270   224
# 2013       TESLA         MODEL S (60 kWh battery)    B   270   335
# 2013       TESLA         MODEL S (85 kWh battery)    B   270   426
# 2013       TESLA              MODEL S PERFORMANCE    B   310   426
# 2014   CHEVROLET                         SPARK EV    B   104   131
# 2014        FORD                   FOCUS ELECTRIC    B   107   122
# 2014  MITSUBISHI                           i-MiEV    B    49   100
# 2014      NISSAN                             LEAF    B    80   135
# 2014       SMART  FORTWO ELECTRIC DRIVE CABRIOLET    B    35   109
# 2014       SMART      FORTWO ELECTRIC DRIVE COUPE    B    35   109
# 2014       TESLA         MODEL S (60 kWh battery)    B   225   335
# 2014       TESLA         MODEL S (85 kWh battery)    B   270   426
# 2014       TESLA              MODEL S PERFORMANCE    B   310   426

# %%
df.loc[[2012, 2014, 2016], ['Make', 'Model', 'TYPE', '(kW)', '(km)']]
# Out:
#             Make                            Model TYPE  (kW)  (km)
# YEAR
# 2012  MITSUBISHI                           i-MiEV    B    49   100
# 2012      NISSAN                             LEAF    B    80   117
# 2014   CHEVROLET                         SPARK EV    B   104   131
# 2014        FORD                   FOCUS ELECTRIC    B   107   122
# 2014  MITSUBISHI                           i-MiEV    B    49   100
# 2014      NISSAN                             LEAF    B    80   135
# 2014       SMART  FORTWO ELECTRIC DRIVE CABRIOLET    B    35   109
# 2014       SMART      FORTWO ELECTRIC DRIVE COUPE    B    35   109
# 2014       TESLA         MODEL S (60 kWh battery)    B   225   335
# 2014       TESLA         MODEL S (85 kWh battery)    B   270   426
# 2014       TESLA              MODEL S PERFORMANCE    B   310   426
# 2016         BMW                               i3    B   125   130
# 2016   CHEVROLET                         SPARK EV    B   104   131
# 2016        FORD                   FOCUS ELECTRIC    B   107   122
# 2016         KIA                          SOUL EV    B    81   149
# 2016  MITSUBISHI                           i-MiEV    B    49   100
# 2016      NISSAN            LEAF (24 kWh battery)    B    80   135
# 2016      NISSAN            LEAF (30 kWh battery)    B    80   172
# 2016       SMART  FORTWO ELECTRIC DRIVE CABRIOLET    B    35   109
# 2016       SMART      FORTWO ELECTRIC DRIVE COUPE    B    35   109
# 2016       TESLA         MODEL S (60 kWh battery)    B   283   335
# 2016       TESLA         MODEL S (70 kWh battery)    B   283   377
# 2016       TESLA      MODEL S (85/90 kWh battery)    B   283   426
# 2016       TESLA                      MODEL S 70D    B   386   386
# 2016       TESLA                  MODEL S 85D/90D    B   386   435
# 2016       TESLA            MODEL S 90D (Refresh)    B   386   473
# 2016       TESLA                MODEL S P85D/P90D    B   568   407
# 2016       TESLA           MODEL S P90D (Refresh)    B   568   435
# 2016       TESLA                      MODEL X 90D    B   386   414
# 2016       TESLA                     MODEL X P90D    B   568   402

# %%
df.loc[df['Make']=='FORD','Make':'TYPE']
# Out:
#       Make           Model     Size  (kW) Unnamed: 5 TYPE
# YEAR
# 2013  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B
# 2014  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B
# 2015  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B
# 2016  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B

# %%
df[(df['Make']=='TESLA') &(df['Model']=='MODEL S 70D')]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Size, (kW), Unnamed: 5, TYPE, CITY (kWh/100 km), HWY (kWh/100 km), COMB (kWh/100 km), CITY (Le/100 km), HWY (Le/100 km), COMB (Le/100 km), (g/km), RATING, (km), TIME (h)]
# Index: []

# %%
df.loc[(df['Make']=='TESLA') &(df['Model']=='MODEL S 70D'), ['Make','Model', 'Size', '(kW)']]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Size, (kW)]
# Index: []

# %%
df.loc[df['Make'].apply(lambda x: len(x)==5)]
# Out:
#        Make                            Model                   Size  (kW)  \
# YEAR
# 2012  Tesla                           i-MiEV             SUBCOMPACT    49
# 2012  Tesla                             LEAF               MID-SIZE    80
# 2013  Tesla                   FOCUS ELECTRIC                COMPACT   107
# 2013  Tesla                           i-MiEV             SUBCOMPACT    49
# 2013  Tesla                             LEAF               MID-SIZE    80
# 2013  Tesla  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER    35
# 2013  Tesla      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER    35
# 2013  Tesla         MODEL S (40 kWh battery)              FULL-SIZE   270
# 2013  Tesla         MODEL S (60 kWh battery)              FULL-SIZE   270
# 2013  Tesla         MODEL S (85 kWh battery)              FULL-SIZE   270
# 2013  Tesla              MODEL S PERFORMANCE              FULL-SIZE   310
# 2014  Tesla                         SPARK EV             SUBCOMPACT   104
# 2014  Tesla                   FOCUS ELECTRIC                COMPACT   107
# 2014  Tesla                           i-MiEV             SUBCOMPACT    49
# 2014  Tesla                             LEAF               MID-SIZE    80
# 2014  Tesla  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER    35
# 2014  Tesla      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER    35
# 2014  Tesla         MODEL S (60 kWh battery)              FULL-SIZE   225
# 2014  Tesla         MODEL S (85 kWh battery)              FULL-SIZE   270
# 2014  Tesla              MODEL S PERFORMANCE              FULL-SIZE   310
# 2015  Tesla                               i3             SUBCOMPACT   125
# 2015  Tesla                         SPARK EV             SUBCOMPACT   104
# 2015  Tesla                   FOCUS ELECTRIC                COMPACT   107
# 2015  Tesla                          SOUL EV  STATION WAGON - SMALL    81
# 2015  Tesla                           i-MiEV             SUBCOMPACT    49
# 2015  Tesla                             LEAF               MID-SIZE    80
# 2015  Tesla  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER    35
# 2015  Tesla      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER    35
# 2015  Tesla         MODEL S (60 kWh battery)              FULL-SIZE   283
# 2015  Tesla         MODEL S (70 kWh battery)              FULL-SIZE   283
# 2015  Tesla      MODEL S (85/90 kWh battery)              FULL-SIZE   283
# 2015  Tesla                      MODEL S 70D              FULL-SIZE   280
# 2015  Tesla                  MODEL S 85D/90D              FULL-SIZE   280
# 2015  Tesla                MODEL S P85D/P90D              FULL-SIZE   515
# 2016  Tesla                               i3             SUBCOMPACT   125
# 2016  Tesla                         SPARK EV             SUBCOMPACT   104
# 2016  Tesla                   FOCUS ELECTRIC                COMPACT   107
# 2016  Tesla                          SOUL EV  STATION WAGON - SMALL    81
# 2016  Tesla                           i-MiEV             SUBCOMPACT    49
# 2016  Tesla            LEAF (24 kWh battery)               MID-SIZE    80
# 2016  Tesla            LEAF (30 kWh battery)               MID-SIZE    80
# 2016  Tesla  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER    35
# 2016  Tesla      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER    35
# 2016  Tesla         MODEL S (60 kWh battery)              FULL-SIZE   283
# 2016  Tesla         MODEL S (70 kWh battery)              FULL-SIZE   283
# 2016  Tesla      MODEL S (85/90 kWh battery)              FULL-SIZE   283
# 2016  Tesla                      MODEL S 70D              FULL-SIZE   386
# 2016  Tesla                  MODEL S 85D/90D              FULL-SIZE   386
# 2016  Tesla            MODEL S 90D (Refresh)              FULL-SIZE   386
# 2016  Tesla                MODEL S P85D/P90D              FULL-SIZE   568
# 2016  Tesla           MODEL S P90D (Refresh)              FULL-SIZE   568
# 2016  Tesla                      MODEL X 90D         SUV - STANDARD   386
# 2016  Tesla                     MODEL X P90D         SUV - STANDARD   568
#
#      Unnamed: 5 TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# YEAR
# 2012         A1    B               16.9              21.4               18.7
# 2012         A1    B               19.3              23.0               21.1
# 2013         A1    B               19.0              21.1               20.0
# 2013         A1    B               16.9              21.4               18.7
# 2013         A1    B               19.3              23.0               21.1
# 2013         A1    B               17.2              22.5               19.6
# 2013         A1    B               17.2              22.5               19.6
# 2013         A1    B               22.4              21.9               22.2
# 2013         A1    B               22.2              21.7               21.9
# 2013         A1    B               23.8              23.2               23.6
# 2013         A1    B               23.9              23.2               23.6
# 2014         A1    B               16.0              19.6               17.8
# 2014         A1    B               19.0              21.1               20.0
# 2014         A1    B               16.9              21.4               18.7
# 2014         A1    B               16.5              20.8               18.4
# 2014         A1    B               17.2              22.5               19.6
# 2014         A1    B               17.2              22.5               19.6
# 2014         A1    B               22.2              21.7               21.9
# 2014         A1    B               23.8              23.2               23.6
# 2014         A1    B               23.9              23.2               23.6
# 2015         A1    B               15.2              18.8               16.8
# 2015         A1    B               16.0              19.6               17.8
# 2015         A1    B               19.0              21.1               20.0
# 2015         A1    B               17.5              22.7               19.9
# 2015         A1    B               16.9              21.4               18.7
# 2015         A1    B               16.5              20.8               18.4
# 2015         A1    B               17.2              22.5               19.6
# 2015         A1    B               17.2              22.5               19.6
# 2015         A1    B               22.2              21.7               21.9
# 2015         A1    B               23.8              23.2               23.6
# 2015         A1    B               23.8              23.2               23.6
# 2015         A1    B               20.8              20.6               20.7
# 2015         A1    B               22.0              19.8               21.0
# 2015         A1    B               23.4              21.5               22.5
# 2016         A1    B               15.2              18.8               16.8
# 2016         A1    B               16.0              19.6               17.8
# 2016         A1    B               19.0              21.1               20.0
# 2016         A1    B               17.5              22.7               19.9
# 2016         A1    B               16.9              21.4               18.7
# 2016         A1    B               16.5              20.8               18.4
# 2016         A1    B               17.0              20.7               18.6
# 2016         A1    B               17.2              22.5               19.6
# 2016         A1    B               17.2              22.5               19.6
# 2016         A1    B               22.2              21.7               21.9
# 2016         A1    B               23.8              23.2               23.6
# 2016         A1    B               23.8              23.2               23.6
# 2016         A1    B               20.8              20.6               20.7
# 2016         A1    B               22.0              19.8               21.0
# 2016         A1    B               20.8              19.7               20.3
# 2016         A1    B               23.4              21.5               22.5
# 2016         A1    B               22.9              21.0               22.1
# 2016         A1    B               23.2              22.2               22.7
# 2016         A1    B               23.6              23.3               23.5
#
#       CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  \
# YEAR
# 2012               1.9              2.4               2.1       0     NaN
# 2012               2.2              2.6               2.4       0     NaN
# 2013               2.1              2.4               2.2       0     NaN
# 2013               1.9              2.4               2.1       0     NaN
# 2013               2.2              2.6               2.4       0     NaN
# 2013               1.9              2.5               2.2       0     NaN
# 2013               1.9              2.5               2.2       0     NaN
# 2013               2.5              2.5               2.5       0     NaN
# 2013               2.5              2.4               2.5       0     NaN
# 2013               2.7              2.6               2.6       0     NaN
# 2013               2.7              2.6               2.6       0     NaN
# 2014               1.8              2.2               2.0       0     NaN
# 2014               2.1              2.4               2.2       0     NaN
# 2014               1.9              2.4               2.1       0     NaN
# 2014               1.9              2.3               2.1       0     NaN
# 2014               1.9              2.5               2.2       0     NaN
# 2014               1.9              2.5               2.2       0     NaN
# 2014               2.5              2.4               2.5       0     NaN
# 2014               2.7              2.6               2.6       0     NaN
# 2014               2.7              2.6               2.6       0     NaN
# 2015               1.7              2.1               1.9       0     NaN
# 2015               1.8              2.2               2.0       0     NaN
# 2015               2.1              2.4               2.2       0     NaN
# 2015               2.0              2.6               2.2       0     NaN
# 2015               1.9              2.4               2.1       0     NaN
# 2015               1.9              2.3               2.1       0     NaN
# 2015               1.9              2.5               2.2       0     NaN
# 2015               1.9              2.5               2.2       0     NaN
# 2015               2.5              2.4               2.5       0     NaN
# 2015               2.7              2.6               2.6       0     NaN
# 2015               2.7              2.6               2.6       0     NaN
# 2015               2.3              2.3               2.3       0     NaN
# 2015               2.5              2.2               2.4       0     NaN
# 2015               2.6              2.4               2.5       0     NaN
# 2016               1.7              2.1               1.9       0    10.0
# 2016               1.8              2.2               2.0       0    10.0
# 2016               2.1              2.4               2.2       0    10.0
# 2016               2.0              2.6               2.2       0    10.0
# 2016               1.9              2.4               2.1       0    10.0
# 2016               1.9              2.3               2.1       0    10.0
# 2016               1.9              2.3               2.1       0    10.0
# 2016               1.9              2.5               2.2       0    10.0
# 2016               1.9              2.5               2.2       0    10.0
# 2016               2.5              2.4               2.5       0    10.0
# 2016               2.7              2.6               2.6       0    10.0
# 2016               2.7              2.6               2.6       0    10.0
# 2016               2.3              2.3               2.3       0    10.0
# 2016               2.5              2.2               2.4       0    10.0
# 2016               2.3              2.2               2.3       0    10.0
# 2016               2.6              2.4               2.5       0    10.0
# 2016               2.6              2.4               2.5       0    10.0
# 2016               2.6              2.5               2.6       0    10.0
# 2016               2.7              2.6               2.6       0    10.0
#
#       (km)  TIME (h)
# YEAR
# 2012   100         7
# 2012   117         7
# 2013   122         4
# 2013   100         7
# 2013   117         7
# 2013   109         8
# 2013   109         8
# 2013   224         6
# 2013   335        10
# 2013   426        12
# 2013   426        12
# 2014   131         7
# 2014   122         4
# 2014   100         7
# 2014   135         5
# 2014   109         8
# 2014   109         8
# 2014   335        10
# 2014   426        12
# 2014   426        12
# 2015   130         4
# 2015   131         7
# 2015   122         4
# 2015   149         4
# 2015   100         7
# 2015   135         5
# 2015   109         8
# 2015   109         8
# 2015   335        10
# 2015   377        12
# 2015   426        12
# 2015   386        12
# 2015   435        12
# 2015   407        12
# 2016   130         4
# 2016   131         7
# 2016   122         4
# 2016   149         4
# 2016   100         7
# 2016   135         5
# 2016   172         6
# 2016   109         8
# 2016   109         8
# 2016   335        10
# 2016   377        12
# 2016   426        12
# 2016   386        12
# 2016   435        12
# 2016   473        12
# 2016   407        12
# 2016   435        12
# 2016   414        12
# 2016   402        12

# %%
df.loc[df['Make'].apply(lambda x: len(x)==5), 'Make':'TYPE']
# Out:
#        Make                            Model                   Size  (kW)  \
# YEAR
# 2012  Tesla                           i-MiEV             SUBCOMPACT    49
# 2012  Tesla                             LEAF               MID-SIZE    80
# 2013  Tesla                   FOCUS ELECTRIC                COMPACT   107
# 2013  Tesla                           i-MiEV             SUBCOMPACT    49
# 2013  Tesla                             LEAF               MID-SIZE    80
# 2013  Tesla  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER    35
# 2013  Tesla      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER    35
# 2013  Tesla         MODEL S (40 kWh battery)              FULL-SIZE   270
# 2013  Tesla         MODEL S (60 kWh battery)              FULL-SIZE   270
# 2013  Tesla         MODEL S (85 kWh battery)              FULL-SIZE   270
# 2013  Tesla              MODEL S PERFORMANCE              FULL-SIZE   310
# 2014  Tesla                         SPARK EV             SUBCOMPACT   104
# 2014  Tesla                   FOCUS ELECTRIC                COMPACT   107
# 2014  Tesla                           i-MiEV             SUBCOMPACT    49
# 2014  Tesla                             LEAF               MID-SIZE    80
# 2014  Tesla  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER    35
# 2014  Tesla      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER    35
# 2014  Tesla         MODEL S (60 kWh battery)              FULL-SIZE   225
# 2014  Tesla         MODEL S (85 kWh battery)              FULL-SIZE   270
# 2014  Tesla              MODEL S PERFORMANCE              FULL-SIZE   310
# 2015  Tesla                               i3             SUBCOMPACT   125
# 2015  Tesla                         SPARK EV             SUBCOMPACT   104
# 2015  Tesla                   FOCUS ELECTRIC                COMPACT   107
# 2015  Tesla                          SOUL EV  STATION WAGON - SMALL    81
# 2015  Tesla                           i-MiEV             SUBCOMPACT    49
# 2015  Tesla                             LEAF               MID-SIZE    80
# 2015  Tesla  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER    35
# 2015  Tesla      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER    35
# 2015  Tesla         MODEL S (60 kWh battery)              FULL-SIZE   283
# 2015  Tesla         MODEL S (70 kWh battery)              FULL-SIZE   283
# 2015  Tesla      MODEL S (85/90 kWh battery)              FULL-SIZE   283
# 2015  Tesla                      MODEL S 70D              FULL-SIZE   280
# 2015  Tesla                  MODEL S 85D/90D              FULL-SIZE   280
# 2015  Tesla                MODEL S P85D/P90D              FULL-SIZE   515
# 2016  Tesla                               i3             SUBCOMPACT   125
# 2016  Tesla                         SPARK EV             SUBCOMPACT   104
# 2016  Tesla                   FOCUS ELECTRIC                COMPACT   107
# 2016  Tesla                          SOUL EV  STATION WAGON - SMALL    81
# 2016  Tesla                           i-MiEV             SUBCOMPACT    49
# 2016  Tesla            LEAF (24 kWh battery)               MID-SIZE    80
# 2016  Tesla            LEAF (30 kWh battery)               MID-SIZE    80
# 2016  Tesla  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER    35
# 2016  Tesla      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER    35
# 2016  Tesla         MODEL S (60 kWh battery)              FULL-SIZE   283
# 2016  Tesla         MODEL S (70 kWh battery)              FULL-SIZE   283
# 2016  Tesla      MODEL S (85/90 kWh battery)              FULL-SIZE   283
# 2016  Tesla                      MODEL S 70D              FULL-SIZE   386
# 2016  Tesla                  MODEL S 85D/90D              FULL-SIZE   386
# 2016  Tesla            MODEL S 90D (Refresh)              FULL-SIZE   386
# 2016  Tesla                MODEL S P85D/P90D              FULL-SIZE   568
# 2016  Tesla           MODEL S P90D (Refresh)              FULL-SIZE   568
# 2016  Tesla                      MODEL X 90D         SUV - STANDARD   386
# 2016  Tesla                     MODEL X P90D         SUV - STANDARD   568
#
#      Unnamed: 5 TYPE
# YEAR
# 2012         A1    B
# 2012         A1    B
# 2013         A1    B
# 2013         A1    B
# 2013         A1    B
# 2013         A1    B
# 2013         A1    B
# 2013         A1    B
# 2013         A1    B
# 2013         A1    B
# 2013         A1    B
# 2014         A1    B
# 2014         A1    B
# 2014         A1    B
# 2014         A1    B
# 2014         A1    B
# 2014         A1    B
# 2014         A1    B
# 2014         A1    B
# 2014         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2015         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
# 2016         A1    B
