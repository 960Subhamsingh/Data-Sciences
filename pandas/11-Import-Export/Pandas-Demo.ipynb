# %%
import pandas as pd

# %%
# column Name
column_name = ['sales_number','sales_order_line','Order_date','customer_Name','Email_Addree','Item','Quantity','unit_Price','Taxt_Amount']

# %%
# read the csv file with column name to use of pandas
df = pd.read_csv('D:/Project/Data Sciences/pandas/2021.csv',names=column_name)

# %%
df.head()
# Out:
#   sales_number  sales_order_line  Order_date   customer_Name  \
# 0      SO49171                 1  2021-01-01   Mariah Foster
# 1      SO49172                 1  2021-01-01    Brian Howard
# 2      SO49173                 1  2021-01-01   Linda Alvarez
# 3      SO49174                 1  2021-01-01  Gina Hernandez
# 4      SO49178                 1  2021-01-01       Beth Ruiz
#
#                    Email_Addree                     Item  Quantity  \
# 0  mariah21@adventure-works.com       Road-250 Black, 48         1
# 1   brian23@adventure-works.com         Road-250 Red, 44         1
# 2   linda19@adventure-works.com  Mountain-200 Silver, 38         1
# 3     gina4@adventure-works.com  Mountain-200 Silver, 42         1
# 4     beth4@adventure-works.com    Road-550-W Yellow, 44         1
#
#    unit_Price  Taxt_Amount
# 0   2181.5625     174.5250
# 1   2443.3500     195.4680
# 2   2071.4196     165.7136
# 3   2071.4196     165.7136
# 4   1000.4375      80.0350

# %%
fit =df['Order_date']== '2021-01-01'
fit_l = df.loc[fit]

# %%
fit_l.to_csv('data/modified.csv')

# %%
fit_l.to_csv('data/modified.tsv', sep='\t')

# %%
fit_l.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx')

# %%
test.head()
# Out:
#    Unnamed: 0 sales_number  sales_order_line  Order_date   customer_Name  \
# 0           0      SO49171                 1  2021-01-01   Mariah Foster
# 1           1      SO49172                 1  2021-01-01    Brian Howard
# 2           2      SO49173                 1  2021-01-01   Linda Alvarez
# 3           3      SO49174                 1  2021-01-01  Gina Hernandez
# 4           4      SO49178                 1  2021-01-01       Beth Ruiz
#
#                    Email_Addree                     Item  Quantity  \
# 0  mariah21@adventure-works.com       Road-250 Black, 48         1
# 1   brian23@adventure-works.com         Road-250 Red, 44         1
# 2   linda19@adventure-works.com  Mountain-200 Silver, 38         1
# 3     gina4@adventure-works.com  Mountain-200 Silver, 42         1
# 4     beth4@adventure-works.com    Road-550-W Yellow, 44         1
#
#    unit_Price  Taxt_Amount
# 0   2181.5625     174.5250
# 1   2443.3500     195.4680
# 2   2071.4196     165.7136
# ...

# %%
fit_l.to_json('data/modified.json', orient='records', lines=True)

# %%
test = pd.read_json('data/modified.json', orient='records', lines=True)

# %%
test.head()
# Out:
#   sales_number  sales_order_line  Order_date   customer_Name  \
# 0      SO49171                 1  2021-01-01   Mariah Foster
# 1      SO49172                 1  2021-01-01    Brian Howard
# 2      SO49173                 1  2021-01-01   Linda Alvarez
# 3      SO49174                 1  2021-01-01  Gina Hernandez
# 4      SO49178                 1  2021-01-01       Beth Ruiz
#
#                    Email_Addree                     Item  Quantity  \
# 0  mariah21@adventure-works.com       Road-250 Black, 48         1
# 1   brian23@adventure-works.com         Road-250 Red, 44         1
# 2   linda19@adventure-works.com  Mountain-200 Silver, 38         1
# 3     gina4@adventure-works.com  Mountain-200 Silver, 42         1
# 4     beth4@adventure-works.com    Road-550-W Yellow, 44         1
#
#    unit_Price  Taxt_Amount
# 0   2181.5625     174.5250
# 1   2443.3500     195.4680
# 2   2071.4196     165.7136
# 3   2071.4196     165.7136
# 4   1000.4375      80.0350

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
# engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

engine = create_engine('postgresql://postgres:tiger@localhost:5420/subham')

# %%
fit_l.to_sql('sample_table', engine, if_exists='replace')
# Out:
# 10

# %%
sql_df = pd.read_sql('sample_table', engine)

# %%
sql_df.head()
# Out:
#    index sales_number  sales_order_line  Order_date   customer_Name  \
# 0      0      SO49171                 1  2021-01-01   Mariah Foster
# 1      1      SO49172                 1  2021-01-01    Brian Howard
# 2      2      SO49173                 1  2021-01-01   Linda Alvarez
# 3      3      SO49174                 1  2021-01-01  Gina Hernandez
# 4      4      SO49178                 1  2021-01-01       Beth Ruiz
#
#                    Email_Addree                     Item  Quantity  \
# 0  mariah21@adventure-works.com       Road-250 Black, 48         1
# 1   brian23@adventure-works.com         Road-250 Red, 44         1
# 2   linda19@adventure-works.com  Mountain-200 Silver, 38         1
# 3     gina4@adventure-works.com  Mountain-200 Silver, 42         1
# 4     beth4@adventure-works.com    Road-550-W Yellow, 44         1
#
#    unit_Price  Taxt_Amount
# 0   2181.5625     174.5250
# 1   2443.3500     195.4680
# 2   2071.4196     165.7136
# 3   2071.4196     165.7136
# ...

# %%
sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine , index_col='sales_number')

# %%
sql_df.head()
# Out:
#               index  sales_order_line  Order_date   customer_Name  \
# sales_number
# SO49171           0                 1  2021-01-01   Mariah Foster
# SO49172           1                 1  2021-01-01    Brian Howard
# SO49173           2                 1  2021-01-01   Linda Alvarez
# SO49174           3                 1  2021-01-01  Gina Hernandez
# SO49178           4                 1  2021-01-01       Beth Ruiz
#
#                               Email_Addree                     Item  Quantity  \
# sales_number
# SO49171       mariah21@adventure-works.com       Road-250 Black, 48         1
# SO49172        brian23@adventure-works.com         Road-250 Red, 44         1
# SO49173        linda19@adventure-works.com  Mountain-200 Silver, 38         1
# SO49174          gina4@adventure-works.com  Mountain-200 Silver, 42         1
# SO49178          beth4@adventure-works.com    Road-550-W Yellow, 44         1
#
#               unit_Price  Taxt_Amount
# sales_number
# ...

# %%
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
posts_df.head()
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1
