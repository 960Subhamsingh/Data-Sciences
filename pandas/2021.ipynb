# %%
import pandas as pd

# %%
df = pd.read_csv('2021.csv')

# %%
# column Name
column_name = ['sales_number','sales_order_line','Order_date','customer_Name','Email_Addree','Item','Quantity','unit_Price','Taxt_Amount']

# %%
# read the csv file with column name to use of pandas
df = pd.read_csv('2021.csv',names=column_name)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28784 entries, 0 to 28783
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sales_number      28784 non-null  object
#  1   sales_order_line  28784 non-null  int64
#  2   Order_date        28784 non-null  object
#  3   customer_Name     28784 non-null  object
#  4   Email_Addree      28784 non-null  object
#  5   Item              28784 non-null  object
#  6   Quantity          28784 non-null  int64
#  7   unit_Price        28784 non-null  float64
#  8   Taxt_Amount       28784 non-null  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB

# %%
# duplicate row

duplicate = df[df.duplicated()]
if not duplicate.empty:
    print("duplicate" , duplicate)
else:
    print("No duplicate rows")
# Out:
# No duplicate rows

# %%
# split the Order_date column into year and month 
df['day', 'Month'] = df['Order_date'].str.slice(8, 10 )
df.head()
# Out:
#   sales_number  sales_order_line  Order_date   customer_Name  \
# 0      SO49171                 1  2021-01-01   Mariah Foster
# 1      SO49172                 1  2021-01-01    Brian Howard
# 2      SO49173                 1  2021-01-01   Linda Alvarez
# 3      SO49174                 1  2021-01-01  Gina Hernandez
# 4      SO49178                 1  2021-01-01       Beth Ruiz
#
#                    Email_Addree                     Item  Quantity  \
# 0  mariah21@adventure-works.com       Road-250 Black, 48         1
# 1   brian23@adventure-works.com         Road-250 Red, 44         1
# 2   linda19@adventure-works.com  Mountain-200 Silver, 38         1
# 3     gina4@adventure-works.com  Mountain-200 Silver, 42         1
# 4     beth4@adventure-works.com    Road-550-W Yellow, 44         1
#
#    unit_Price  Taxt_Amount (day, Month)
# 0   2181.5625     174.5250           01
# 1   2443.3500     195.4680           01
# 2   2071.4196     165.7136           01
# 3   2071.4196     165.7136           01
# 4   1000.4375      80.0350           01

# %% [markdown]
# ### display all the inforamtion of row number 2

# %%
df.iloc[6,[3]]
# Out:
# customer_Name    Margaret Guo
# Name: 6, dtype: object

# %% [markdown]
# dispaly the name of  row no 6,4

# %%
df.loc[[6,4], 'customer_Name']
# Out:
# 6    Margaret Guo
# 4       Beth Ruiz
# Name: customer_Name, dtype: object

# %%
df.iloc[[3,2,1]]
# Out:
#   sales_number  sales_order_line  Order_date   customer_Name  \
# 3      SO49174                 1  2021-01-01  Gina Hernandez
# 2      SO49173                 1  2021-01-01   Linda Alvarez
# 1      SO49172                 1  2021-01-01    Brian Howard
#
#                   Email_Addree                     Item  Quantity  unit_Price  \
# 3    gina4@adventure-works.com  Mountain-200 Silver, 42         1   2071.4196
# 2  linda19@adventure-works.com  Mountain-200 Silver, 38         1   2071.4196
# 1  brian23@adventure-works.com         Road-250 Red, 44         1   2443.3500
#
#    Taxt_Amount (day, Month)
# 3     165.7136           01
# 2     165.7136           01
# 1     195.4680           01

# %%
df[['sales_number','sales_order_line','Order_date','customer_Name']][2:6]
# Out:
#   sales_number  sales_order_line  Order_date   customer_Name
# 2      SO49173                 1  2021-01-01   Linda Alvarez
# 3      SO49174                 1  2021-01-01  Gina Hernandez
# 4      SO49178                 1  2021-01-01       Beth Ruiz
# 5      SO49179                 1  2021-01-01       Evan Ward

# %%
# See the 2nd row of existing  column of  customer_Name 
df.customer_Name.iloc[[2]]
# Out:
# 2    Linda Alvarez
# Name: customer_Name, dtype: object

# %%
df[df['Order_date']>'2021-01-01'].head(2)
# Out:
#    sales_number  sales_order_line  Order_date customer_Name  \
# 10      SO49186                 1  2021-01-02       Cara Xu
# 11      SO49187                 1  2021-01-02     Lacey Liu
#
#                    Email_Addree                Item  Quantity  unit_Price  \
# 10    cara8@adventure-works.com    Road-250 Red, 52         1   2443.3500
# 11  lacey16@adventure-works.com  Road-250 Black, 58         1   2181.5625
#
#     Taxt_Amount (day, Month)
# 10      195.468           02
# 11      174.525           02

# %%
df[(df['Order_date']=='2021-01-01') | (df['customer_Name']=='Mariah Foster')].head(2)
# Out:
#   sales_number  sales_order_line  Order_date  customer_Name  \
# 0      SO49171                 1  2021-01-01  Mariah Foster
# 1      SO49172                 1  2021-01-01   Brian Howard
#
#                    Email_Addree                Item  Quantity  unit_Price  \
# 0  mariah21@adventure-works.com  Road-250 Black, 48         1   2181.5625
# 1   brian23@adventure-works.com    Road-250 Red, 44         1   2443.3500
#
#    Taxt_Amount (day, Month)
# 0      174.525           01
# 1      195.468           01

# %%
df.agg(['min','max'])
# Out:
#     sales_number  sales_order_line  Order_date customer_Name  \
# min      SO49171                 1  2021-01-01   Aaron Adams
# max      SO63118                 8  2021-12-31    Zoe Torres
#
#                     Email_Addree                        Item  Quantity  \
# min  aaron11@adventure-works.com                AWC Logo Cap         1
# max     zoe9@adventure-works.com  Women's Mountain Shorts, S         1
#
#      unit_Price  Taxt_Amount (day, Month)
# min        2.29       0.1832           01
# max     2443.35     195.4680           31

# %%
df['Quantity'].median()
# Out:
# 1.0

# %%
df[df['customer_Name'].str.split().apply(lambda x: len(x)== 3)]
# Out:
#      sales_number  sales_order_line  Order_date               customer_Name  \
# 4295      SO52413                 1  2021-07-12           Pablo Rovira Diez
# 4296      SO52413                 2  2021-07-12           Pablo Rovira Diez
# 4297      SO52413                 3  2021-07-12           Pablo Rovira Diez
# 6763      SO53640                 1  2021-08-01  Francisco Javier Castrej�n
#
#                         Email_Addree                        Item  Quantity  \
# 4295      pablo0@adventure-works.com          Mountain Tire Tube         1
# 4296      pablo0@adventure-works.com            HL Mountain Tire         1
# 4297      pablo0@adventure-works.com         Patch Kit/8 Patches         1
# 6763  francisco0@adventure-works.com  Women's Mountain Shorts, L         1
#
#       unit_Price  Taxt_Amount (day, Month)
# 4295        4.99       0.3992           12
# 4296       35.00       2.8000           12
# 4297        2.29       0.1832           12
# 6763       69.99       5.5992           01

# %%
order_date_index= df.columns.get_loc('Order_date')

# insert year column after order_date

df.insert(order_date_index + 1 'year' , df.pop('year'))
df.insert(order_date_index + 1 'month' , df.pop('month'))
# Out:
#   Cell In[9], line 5
#     df.insert(order_date_index + 1 'year' , df.pop('year'))
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# drop the day column

df.drop('day', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['sales_number', 'sales_order_line', 'Order_date', 'customer_Name',
#        'Email_Addree', 'Item', 'Quantity', 'unit_Price', 'Taxt_Amount'],
#       dtype='object')

# %%
df['Item'].value_counts(normalize=True)
# Out:
# Item
# Water Bottle - 30 oz.      0.072853
# Patch Kit/8 Patches        0.056316
# Mountain Tire Tube         0.054926
# Road Tire Tube             0.042107
# Sport-100 Helmet, Red      0.038077
#                              ...
# Mountain-500 Silver, 44    0.000660
# Road-650 Black, 44         0.000625
# Mountain-500 Black, 52     0.000556
# Mountain-500 Silver, 40    0.000556
# Road-650 Red, 60           0.000486
# Name: proportion, Length: 117, dtype: float64

# %%
df
# Out:
#       sales_number  sales_order_line  Order_date   customer_Name  \
# 0          SO49171                 1  2021-01-01   Mariah Foster
# 1          SO49172                 1  2021-01-01    Brian Howard
# 2          SO49173                 1  2021-01-01   Linda Alvarez
# 3          SO49174                 1  2021-01-01  Gina Hernandez
# 4          SO49178                 1  2021-01-01       Beth Ruiz
# ...            ...               ...         ...             ...
# 28779      SO63093                 2  2021-12-31  Rebekah Martin
# 28780      SO63113                 1  2021-12-31  Carolyn Alonso
# 28781      SO63113                 2  2021-12-31  Carolyn Alonso
# 28782      SO63066                 1  2021-12-31  Teresa Navarro
# 28783      SO63066                 2  2021-12-31  Teresa Navarro
#
#                         Email_Addree                            Item  \
# 0       mariah21@adventure-works.com              Road-250 Black, 48
# 1        brian23@adventure-works.com                Road-250 Red, 44
# 2        linda19@adventure-works.com         Mountain-200 Silver, 38
# 3          gina4@adventure-works.com         Mountain-200 Silver, 42
# 4          beth4@adventure-works.com           Road-550-W Yellow, 44
# ...                              ...                             ...
# 28779  rebekah20@adventure-works.com             Patch Kit/8 Patches
# 28780  carolyn29@adventure-works.com           Road-550-W Yellow, 48
# 28781  carolyn29@adventure-works.com  Short-Sleeve Classic Jersey, S
# 28782   teresa10@adventure-works.com              Mountain Tire Tube
# 28783   teresa10@adventure-works.com             Patch Kit/8 Patches
#
#        Quantity  unit_Price  Taxt_Amount
# 0             1   2181.5625     174.5250
# 1             1   2443.3500     195.4680
# 2             1   2071.4196     165.7136
# 3             1   2071.4196     165.7136
# 4             1   1000.4375      80.0350
# ...         ...         ...          ...
# 28779         1      2.2900       0.1832
# 28780         1   1120.4900      89.6392
# 28781         1     53.9900       4.3192
# 28782         1      4.9900       0.3992
# 28783         1      2.2900       0.1832
#
# [28784 rows x 9 columns]

# %%
df.dropna()
# Out:
#       sales_number  sales_order_line  Order_date   customer_Name  \
# 0          SO49171                 1  2021-01-01   Mariah Foster
# 1          SO49172                 1  2021-01-01    Brian Howard
# 2          SO49173                 1  2021-01-01   Linda Alvarez
# 3          SO49174                 1  2021-01-01  Gina Hernandez
# 4          SO49178                 1  2021-01-01       Beth Ruiz
# ...            ...               ...         ...             ...
# 28779      SO63093                 2  2021-12-31  Rebekah Martin
# 28780      SO63113                 1  2021-12-31  Carolyn Alonso
# 28781      SO63113                 2  2021-12-31  Carolyn Alonso
# 28782      SO63066                 1  2021-12-31  Teresa Navarro
# 28783      SO63066                 2  2021-12-31  Teresa Navarro
#
#                         Email_Addree                            Item  \
# 0       mariah21@adventure-works.com              Road-250 Black, 48
# 1        brian23@adventure-works.com                Road-250 Red, 44
# 2        linda19@adventure-works.com         Mountain-200 Silver, 38
# 3          gina4@adventure-works.com         Mountain-200 Silver, 42
# 4          beth4@adventure-works.com           Road-550-W Yellow, 44
# ...                              ...                             ...
# 28779  rebekah20@adventure-works.com             Patch Kit/8 Patches
# 28780  carolyn29@adventure-works.com           Road-550-W Yellow, 48
# 28781  carolyn29@adventure-works.com  Short-Sleeve Classic Jersey, S
# 28782   teresa10@adventure-works.com              Mountain Tire Tube
# 28783   teresa10@adventure-works.com             Patch Kit/8 Patches
#
#        Quantity  unit_Price  Taxt_Amount
# 0             1   2181.5625     174.5250
# 1             1   2443.3500     195.4680
# 2             1   2071.4196     165.7136
# 3             1   2071.4196     165.7136
# 4             1   1000.4375      80.0350
# ...         ...         ...          ...
# 28779         1      2.2900       0.1832
# 28780         1   1120.4900      89.6392
# 28781         1     53.9900       4.3192
# 28782         1      4.9900       0.3992
# 28783         1      2.2900       0.1832
#
# [28784 rows x 9 columns]
