# %%
import pandas as pd

# %%
stocks= pd.read_csv("D:/Project/Data-Sciences/pandas/13- style DataFrame/stock.csv")

# %%
stocks
# Out:
#        Date   Close    Volume Symbol
# 0  03-10-16   31.50  14070500   CSCO
# 1  03-10-16  112.52  21701800   AAPL
# 2  03-10-16   57.42  19189500   MSFT
# 3  04-10-16  113.00  29736800   AAPL
# 4  04-10-16   57.24  20085900   MSFT
# 5  04-10-16   31.35  18460400   CSCO
# 6  05-10-16   57.64  16726400   MSFT
# 7  05-10-16   31.59  11808600   CSCO
# 8  05-10-16  113.05  21453100   AAPL

# %%
stock= pd.read_csv("D:/Project/Data-Sciences/pandas/13- style DataFrame/stock.csv", index_col="Date")

# %%
stock.head()
# Out:
#            Close    Volume Symbol
# Date
# 03-10-16   31.50  14070500   CSCO
# 03-10-16  112.52  21701800   AAPL
# 03-10-16   57.42  19189500   MSFT
# 04-10-16  113.00  29736800   AAPL
# 04-10-16   57.24  20085900   MSFT

# %%
stocks.sort_index(inplace=True)

# %%
stocks.sort_index( )
# Out:
#        Date   Close    Volume Symbol
# 0  03-10-16   31.50  14070500   CSCO
# 1  03-10-16  112.52  21701800   AAPL
# 2  03-10-16   57.42  19189500   MSFT
# 3  04-10-16  113.00  29736800   AAPL
# 4  04-10-16   57.24  20085900   MSFT
# 5  04-10-16   31.35  18460400   CSCO
# 6  05-10-16   57.64  16726400   MSFT
# 7  05-10-16   31.59  11808600   CSCO
# 8  05-10-16  113.05  21453100   AAPL

# %% [markdown]
#  Read a .csv from a URL with Pandas

# %% [markdown]
# Target website: https://www.football-data.co.uk/data.php

# %%
web_data= pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/E0.csv')

# %%
web_data1 = web_data.rename(columns={'Date':'date',
                                            'HomeTeam':'home_team',
                                            'AwayTeam':'away_team',
                                            'FTHG': 'home_goals',
                                            'FTAG': 'away_goals'})

# %% [markdown]
# Read HTML
# Target Website: https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)

# %%
read_html = pd.read_html('https://www.bbc.com/sport/football/premier-league/table')

# %%
# read_html= pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes#Series_overview')

# %%
read_html
# Out:
# [                         Team  Played  Won  Drawn  Lost  Goals For  \
#  0                    1Arsenal      31   21      7     3         61
#  1            2Manchester City      30   18      7     5         60
#  2          3Manchester United      31   15     10     6         56
#  3                4Aston Villa      31   16      6     9         42
#  4                  5Liverpool      31   14      7    10         50
#  5                    6Chelsea      31   13      9     9         53
#  6                  7Brentford      31   13      7    11         46
#  7                    8Everton      31   13      7    11         37
#  8                     9Fulham      31   13      5    13         43
#  9    10Brighton & Hove Albion      31   11     10    10         41
#  10               11Sunderland      31   11     10    10         32
#  11         12Newcastle United      31   12      6    13         44
#  12          13AFC Bournemouth      31    9     15     7         46
# ...
