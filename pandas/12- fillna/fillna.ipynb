# %%
import pandas as pd
import seaborn as sns

# %%
order = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv',sep='\t')

# %%
order.dropna(subset=['item_name', 'quantity','choice_description'])
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %%
order1 = order.fillna("0")

# %% [markdown]
# # Fillna function

# %% [markdown]
# fill different values in null in different column

# %%
order2 = order.fillna({
    'choice_description' : "nothing"
    #add many column
})

# %%
order2.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa            nothing
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %% [markdown]
# # these code are use to delete the value of above existing

# %%
# order.fillna(method='ffill').head(4)
# filling null values with  the nxt values
# order.fillna(method='bfill').head(4)
order.fillna(method='pad').head(4)
order.interpolate().head(4)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12968\2925142511.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   order.fillna(method='pad').head(4)
# C:\Users\hp\AppData\Local\Temp\ipykernel_12968\2925142511.py:5: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   order.interpolate().head(4)
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description item_price
# 0                NaN     $2.39
# 1       [Clementine]     $3.39
# 2            [Apple]     $3.39
# 3                NaN     $2.39

# %%
order.fillna(method='bfill' , axis=1)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12968\3679837423.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   order.fillna(method='bfill' , axis=1)
#      order_id quantity                              item_name  \
# 0           1        1           Chips and Fresh Tomato Salsa
# 1           1        1                                   Izze
# 2           1        1                       Nantucket Nectar
# 3           1        1  Chips and Tomatillo-Green Chili Salsa
# 4           2        2                           Chicken Bowl
# ...       ...      ...                                    ...
# 4617     1833        1                          Steak Burrito
# 4618     1833        1                          Steak Burrito
# 4619     1834        1                     Chicken Salad Bowl
# 4620     1834        1                     Chicken Salad Bowl
# ...

# %%
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd'],
         'Mobile No': [97, 91, 58, 76]}

# Define a dictionary containing employee data
data2 = {'Name': ['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'],
         'Age': [22, 32, 12, 52],
         'Address': ['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'],
         'Qualification': ['MCA', 'Phd', 'Bcom', 'B.hons'],
         'Salary': [1000, 2000, 3000, 4000]}

# %%
# Convert the dictionary into DataFrame
df = pd.DataFrame(data1, index=[0, 1, 2, 3])

# Convert the dictionary into DataFrame
df1 = pd.DataFrame(data2, index=[2, 3, 6, 7])

# %%
pd.concat([df,df])
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76

# %%
data= pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")

# %% [markdown]
# Fill na  values

# %%
data1 = data.fillna(value=0)
data1.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                  0  5000000.0

# %%
# fill null value with the mean of a column
df= data.fillna(value=data['College'].mean)

# %% [markdown]
# drop nan row

# %%
data4 = data.dropna()
data4.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0
# 6            LSU  1170960.0
# 7        Gonzaga  2165160.0

# %% [markdown]
# # replace

# %%
import numpy as np
data5 = data.replace(to_replace=np.nan, value=8988)

# %% [markdown]
# # interpolate

# %%
data6['College']= data['College'].interpolate(method='linear' )
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6940\3721793061.py:1: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data6['College']= data['College'].interpolate(method='linear')

# %% [markdown]
#  concatenating team with name column
#  overwriting name column

# %%
new_data = data["Name"].copy()
data['New_name'] = data['Name'].str.cat(new_data, sep=",")

# %%
# making copy of team column
new = data["Team"].copy()
 
# string to replace null values with
na_string ="No College"
 
# concatenating team with name column
# overwriting name column
data["College"]= data["College"].str.cat(new, sep =", ", na_rep = na_string)
