# %% [markdown]
# ### This assignment is for visualization using Python Matplotlib Library

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# + car runing Par days with in speed
#
# Days=[1,2,3,4,5,6,7,8]
#
# Speed=[60,62,61,58,56,57,46,63]

# %%
Days=np.array([1,2,3,4,5,6,7,8])
Speed=np.array([60,62,61,58,56,57,46,63])

plt.plot(Days, Speed , linewidth= 4 ,  marker='o' , color='Orange')
plt.xlabel('Days')
plt.ylabel('Month')
# plt.figure(figsize=(15,6))
plt.title('Car-Speed Measure')
# Out:
# Text(0.5, 1.0, 'Car-Speed Measure')

# %% [markdown]
# see on the chart of  minimum, maximum  & avg spped of 8 days
# Grid in Car minimum, Maximum and average speed in 8 days.

# %%
days=np.array([1,2,3,4,5,6,7,8])
max_speed=np.array([80,91,92,88,77,79,76,75])
min_speed=np.array([42,43,40,42,33,36,34,35])
avg_speed=np.array([46,58,57,56,40,42,41,36])
plt.plot(days,max_speed,label='max_speed')
plt.plot(days,min_speed,label='min_speed')
plt.plot(days,avg_speed,label='avg_speed')
plt.legend()
plt.grid()

# %% [markdown]
# Simple bar chart showing popularity of Programming Languages.
#
# Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
# Popularity = [56, 39, 34, 34, 29]
# Security = [44 ,36 ,55, 50, 42]

# %%
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]

X_axis = np.arange(len(Languages))
plt.bar(X_axis - 0.2, Popularity, 0.4, label = 'Popularity')
plt.bar(X_axis + 0.2, Security, 0.4, label = 'Security')
plt.xlabel('Languages')
plt.legend()
plt.ylabel("Popularity ")
plt.title('Information')
plt.show()

# %% [markdown]
# sample data of Students marks of various Students
#
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
#
# Histogram showing Below Average, Average and Execellent distribution
#
# 40-60: Below Average
#
# 60-80: Average
#
# 80-100: Excellent

# %%
Marks = np.array([61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])
below_average = Marks[np.logical_and(Marks >= 40,Marks < 60)]
average = Marks[np.logical_and(Marks >= 60,Marks < 80)]
excellent = Marks[np.logical_and(Marks >= 80,Marks < 100)]

plt.figure(figsize=(12,6))
plt.hist(Marks, align='right', color='green', edgecolor='black')
plt.xlabel('Bins')
plt.ylabel('Marks')
plt.title('Histogram of Marks')
plt.vlines([40, 60, 80,100], ymin=0, ymax=4, colors='k',linestyles='dashed')
plt.show()
print(f'No of Below Average students : {below_average.size}')
print(f'No of Average students : {average.size}')
print(f'No of Excellent students : {excellent.size}')
# Out:
# No of Below Average students : 5
# No of Average students : 8
# No of Excellent students : 4
