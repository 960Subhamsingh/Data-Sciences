# %% [markdown]
# ## Numpy & Scipy
# Numpy stands for Numerical Python and Scipy stands for Scientific Python. Numpy and Scipy are fundamental packages for scientific computation/programming.
#
# Scientific Programmimg deals with solving scientific or mathematical problems with the help of computer. Scientific Languages are MATLAB, FORTRAN, ALGOL, APL, etc.

# %% [markdown]
# ## Why Numpy & Scipy?
# The basic operations used in Scientific programming includes array, matrices, integration, differential equation solver, statistics, etc. But python bydefault don,t have any of the fundamental built-in except for some basic operations. Numpy specialised in numerical proccesing through multidimentional array. Scipy is built on the Numpy framework and take the whole scientific to new level by supporting advanced mathmatical functions.

# %% [markdown]
# ## Descriptive Statistics
# Descriptive Statistics process describes the basic features of data in a study. It delivers summaries on the sample and the measures and does not use the data to learn about the population it represents.

# %%
# importing neccesary libraries
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("E:/IMDB_movies-main/IMDB_movies-main/IMDB-Movie-Data.csv")

# %%
import scipy

from scipy import stats

# %%
y = data.Year
y.value_counts()
# Out:
# Year
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: count, dtype: int64

# %%
a = np.random.randint(265)
a
# Out:
# 150

# %%
from numpy import random
random.rand(2,3) #rand() method returns a random float between 0 and 1.
# Out:
# array([[0.06763788, 0.49002711, 0.3378132 ],
#        [0.0573995 , 0.25044371, 0.30831455]])

# %% [markdown]
# ### Random distributions with numpy and scipy
# A random distribution is a set of random numbers that follow a certain probability density function.

# %%
x = random.choice([4, 6, 3, 5], p=[0.1, 0.3, 0.6, 0.0], size=(2,2))
x
# Out:
# array([[6, 3],
#        [4, 3]])

# %%
import matplotlib.pyplot as plt
from scipy.stats import alpha
a =5
r = alpha.rvs(a, size=500)
plt.plot(r)
